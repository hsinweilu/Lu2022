# %%
import matplotlib.pyplot as plt
import pickle

plt.style.use('./paper.mplstyle')

# %% [markdown]
# ## Fig 2A

# %%
fig = pickle.load(open("./data/fig2A.pickle", "rb"))
fig
# Out:
# /Users/hsinwei/pyvenv/cnmodel/lib/python3.8/site-packages/IPython/core/pylabtools.py:132: UserWarning: Calling figure.constrained_layout, but figure not setup to do constrained layout.  You either called GridSpec without the fig keyword, you are using plt.subplot, or you need to call figure or subplots with the constrained_layout=True kwarg.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### Data can be extracted from the objects in the figure

# %%
# extract data from ax#6
x = fig.get_children()[6].get_children()[0].get_xdata()
y = fig.get_children()[6].get_children()[0].get_ydata()
plt.scatter(x, y)
