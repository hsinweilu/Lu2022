# %% [markdown]
# # Fig1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

plt.style.use('./paper.mplstyle')

# %% [markdown]
# ## Fig 1A

# %%
fig = pickle.load(open("./data/fig1A.pickle", "rb"))
fig
# Out:
# /Users/hsinwei/pyvenv/cnmodel/lib/python3.8/site-packages/IPython/core/pylabtools.py:132: UserWarning: Calling figure.constrained_layout, but figure not setup to do constrained layout.  You either called GridSpec without the fig keyword, you are using plt.subplot, or you need to call figure or subplots with the constrained_layout=True kwarg.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Fig 1C

# %%
fig = pickle.load(open("./data/fig1C.pickle", "rb"))
fig

# %% [markdown]
# ## fig 1D, E

# %%
fig = pickle.load(open("./data/fig1DE.pickle", "rb"))
fig

# %% [markdown]
# ## Fig 1F, G

# %%
fig = pickle.load(open("./data/fig1FG.pickle", "rb"))
fig

# %% [markdown]
# ## Fig 1H

# %%
fig = pickle.load(open("./data/fig1H.pickle", "rb"))
fig

# %% [markdown]
# ## Fig 1I, J

# %%
fig = pickle.load(open("./data/fig1IJ.pickle", "rb"))
fig

# %% [markdown]
# ## Fig 1K

# %%
fig = pickle.load(open("./data/fig1K.pickle", "rb"))
fig

# %% [markdown]
# ## Fig 1L

# %%
fig = pickle.load(open("./data/fig1L.pickle", "rb"))
fig

# %% [markdown]
# ## Data for Fig 1K, L

# %%
# data for oi cells
pd.read_pickle('./data/fig1KL_oidata.pkl')
# Out:
#     iDataset iCell iRecOfCell expname celltype  \
# 11        12     1         12  B18568       Oi
# 22        23     1         23  B18580       Oi
# 11        12     2         10  B18581       Oi
# 30        31     2         28  B19005       Oi
# 27        28     6          4  B19031       Oi
# 24        25     1         25  B19088       Oi
# 3          4     1          4  B19092       Oi
# 36        37     1         37  B19093       Oi
# 6          7     1          7  B19119       Oi
# 5          6     2          6  B19124       Oi
# 17        18     1         18  B19135       Oi
# 78        79    16         13  L17539       Oi
# 130      131    29          8  L17543       Oi
# 21        22     7          5  L18582       Oi
# 27        28     8          5  L18585       Oi
# 51        52    21          6  L18586       Oi
# 34        35    10          5  L18591       Oi
# 20        21     6          5  L18591       Oi
# 34        35     5         14  L19009       Oi
# ...

# %%
# data for an fibers
pd.read_pickle('./data/fig1KL_andata.pkl')
# Out:
#    iDataset iCell iRecOfCell expname celltype  \
# 72       73    15          5  B19031       PL
# 26       27     4         10  L17537       PL
# 42       43     6          8  L17537       PL
# 51       52    12         12  L17539       PL
# 46       47    12          9  L17543       PL
# ..      ...   ...        ...     ...      ...
# 20       21     1         21  L21001       AN
# 35       36     2          8  L21001       AN
# 38       39     3          3  L21001       AN
# 49       50     8         15  Z19083       AN
# 85       86     9          7  Z19083       AN
#
#                                                     c     f0   spl  \
# 72  [-1.0, -0.75, -0.5, -0.25, 0.0, 0.25, 0.5, 0.7...  100.0  40.0
# 26  [-1.0, -0.75, -0.5, -0.25, 0.0, 0.25, 0.5, 0.7...   50.0  60.0
# 42  [-1.0, -0.75, -0.5, -0.25, 0.0, 0.25, 0.5, 0.7...   50.0  60.0
# 51  [-1.0, -0.75, -0.5, -0.25, 0.0, 0.25, 0.5, 0.7...  300.0  60.0
# 46  [-1.0, -0.75, -0.5, -0.25, 0.0, 0.25, 0.5, 0.7...  200.0  60.0
# ...
